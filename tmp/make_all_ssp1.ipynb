# %%
import pandas as pd

# %%
city_names = ['Seoul', 'Shanghai', 'Tokyo', 'Bangkok', 'Jakarta']

# %%
seoul = pd.read_csv('/Users/juyeonm1/Desktop/CAPSTONE/TFT_model/SSP1/TFT_SSP1_forecast/tft_ssp1_Seoul_V2.csv')
seoul.rename(columns={'DateTime':'Dt', 'Monthly Anamoly':'Temperature'}, inplace=True)
seoul['Country'] = pd.Series(['South Korea' for i in range(2640)])
seoul = seoul[['Country', 'Dt', 'Temperature']]
seoul
# Out:
#           Country          Dt  Temperature
# 0     South Korea  1880-01-01    -5.194000
# 1     South Korea  1880-02-01    -1.075000
# 2     South Korea  1880-03-01     4.233000
# 3     South Korea  1880-04-01     9.538000
# 4     South Korea  1880-05-01    15.957000
# ...           ...         ...          ...
# 2635  South Korea  2099-08-01    17.515082
# 2636  South Korea  2099-09-01    12.208323
# 2637  South Korea  2099-10-01    10.130891
# 2638  South Korea  2099-11-01     8.453711
# 2639  South Korea  2099-12-01    10.644063
#
# [2640 rows x 3 columns]

# %%
shanghai = pd.read_csv('/Users/juyeonm1/Desktop/CAPSTONE/TFT_model/SSP1/TFT_SSP1_forecast/tft_ssp1_Shanghai_V2.csv')
shanghai.rename(columns={'DateTime':'Dt', 'Monthly Anamoly':'Temperature'}, inplace=True)
shanghai['Country'] = pd.Series(['China' for i in range(2640)])
shanghai = shanghai[['Country', 'Dt', 'Temperature']]
shanghai
# Out:
#      Country          Dt  Temperature
# 0      China  1880-01-01     1.836000
# 1      China  1880-02-01     4.134000
# 2      China  1880-03-01     8.959000
# 3      China  1880-04-01    13.445000
# 4      China  1880-05-01    20.229000
# ...      ...         ...          ...
# 2635   China  2099-08-01    21.366693
# 2636   China  2099-09-01    23.930978
# 2637   China  2099-10-01    22.426376
# 2638   China  2099-11-01    21.659669
# 2639   China  2099-12-01    17.879618
#
# [2640 rows x 3 columns]

# %%
Tokyo = pd.read_csv('/Users/juyeonm1/Desktop/CAPSTONE/TFT_model/SSP1/TFT_SSP1_forecast/tft_ssp1_Tokyo_V2.csv')
Tokyo.rename(columns={'DateTime':'Dt', 'Monthly Anamoly':'Temperature'}, inplace=True)
Tokyo['Country'] = pd.Series(['Japan' for i in range(2640)])
Tokyo[['Country', 'Dt', 'Temperature']]
Tokyo
# Out:
#               Dt  Temperature Country
# 0     1880-01-01    -0.139000   Japan
# 1     1880-02-01     3.050000   Japan
# 2     1880-03-01     6.034000   Japan
# 3     1880-04-01     9.972000   Japan
# 4     1880-05-01    15.601000   Japan
# ...          ...          ...     ...
# 2635  2099-08-01    16.681297   Japan
# 2636  2099-09-01    17.905993   Japan
# 2637  2099-10-01    18.962962   Japan
# 2638  2099-11-01    19.589026   Japan
# 2639  2099-12-01    14.284825   Japan
#
# [2640 rows x 3 columns]

# %%
Jakarta = pd.read_csv('/Users/juyeonm1/Desktop/CAPSTONE/TFT_model/SSP1/TFT_SSP1_forecast/tft_ssp1_Jakarta_V2.csv')
Jakarta.rename(columns={'DateTime':'Dt', 'Monthly Anamoly':'Temperature'}, inplace=True)
Jakarta['Country'] = pd.Series(['Indonesia' for i in range(2640)])
Jakarta[['Country', 'Dt', 'Temperature']]
Jakarta
# Out:
#               Dt  Temperature    Country
# 0     1880-01-01    24.819000  Indonesia
# 1     1880-02-01    26.806000  Indonesia
# 2     1880-03-01    28.375000  Indonesia
# 3     1880-04-01    28.941000  Indonesia
# 4     1880-05-01    28.820000  Indonesia
# ...          ...          ...        ...
# 2635  2099-08-01    28.499710  Indonesia
# 2636  2099-09-01    28.129022  Indonesia
# 2637  2099-10-01    28.177173  Indonesia
# 2638  2099-11-01    28.501043  Indonesia
# 2639  2099-12-01    28.720479  Indonesia
#
# [2640 rows x 3 columns]

# %%
Bangkok = pd.read_csv('/Users/juyeonm1/Desktop/CAPSTONE/TFT_model/SSP1/TFT_SSP1_forecast/tft_ssp1_Bangkok_V2.csv')
Bangkok.rename(columns={'DateTime':'Dt', 'Monthly Anamoly':'Temperature'}, inplace=True)
Bangkok['Country'] = pd.Series(['Thailand' for i in range(2640)])
Bangkok[['Country', 'Dt', 'Temperature']]
Bangkok
# Out:
#               Dt  Temperature   Country
# 0     1880-01-01    25.046000  Thailand
# 1     1880-02-01    26.103000  Thailand
# 2     1880-03-01    26.561000  Thailand
# 3     1880-04-01    26.476000  Thailand
# 4     1880-05-01    26.891000  Thailand
# ...          ...          ...       ...
# 2635  2099-08-01    27.411870  Thailand
# 2636  2099-09-01    27.681862  Thailand
# 2637  2099-10-01    27.347757  Thailand
# 2638  2099-11-01    27.638066  Thailand
# 2639  2099-12-01    27.502796  Thailand
#
# [2640 rows x 3 columns]

# %%
all = pd.concat([seoul, shanghai, Tokyo, Jakarta, Bangkok], axis=0)

# %%
all.to_csv('tft_ssp1.csv')
